# %% [markdown]
# <h2 style="color:red">Practical : 3</h2>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
import os

# os we use to save dirictory path , so we cannot needs to enter full path again n again.

# %%
os.chdir('C:/Users/MSCIT/Downloads/Datasets-20220805T064950Z-001/Datasets')
# here we saved our dataset path one time only.

cars = pd.read_csv('Toyota.csv', index_col=0, na_values=["??","???"])
cars.size

# index_col=0, make first column (which is at index 0) Primary Key,
# na_values=["??","???"] : here in our data we have values "??" , "???" ,
#                          I dont want to consider this value so I am making it as Null values.

# now chcek data size
# Out:
# 14360

# %%
cars.dropna(axis=0,inplace=True)
cars.size

# I am dropping null values 
# again check data size , it reduced.
# Out:
# 10990

# %%
cars = pd.read_csv('Toyota.csv', index_col=0)
cars.head()
# Out:
#    Price   Age     KM FuelType  HP  MetColor  Automatic    CC  Doors  Weight
# 0  13500  23.0  46986   Diesel  90       1.0          0  2000  three    1165
# 1  13750  23.0  72937   Diesel  90       1.0          0  2000      3    1165
# 2  13950  24.0  41711   Diesel  90       NaN          0  2000      3    1165
# 3  14950  26.0  48000   Diesel  90       0.0          0  2000      3    1165
# 4  13750  30.0  38500   Diesel  90       0.0          0  2000      3    1170

# %%
sns.set(style="darkgrid")
sns.regplot(x=cars['Age'],y = cars['Price'])

# it estimates and plots a regression model relating the x and y variables.

# regplot will draw line between scatter plot / points.

# %%
# if we dont want line use : fit_reg = False

sns.set(style="darkgrid")
sns.regplot(x=cars['Age'],y = cars['Price'],marker = "*", fit_reg = False)

# it estimates and plots a regression model relating the x and y variables.

# regplot will draw line between scatter plot / points.
# marker = "*" for style.

# %%
sns.lmplot(data = cars,x ='Age', y ='Price', fit_reg = False, hue='FuelType', legend = True, palette="Set1")

# hue='FuelType' This is 3rd values which I am comparing with other two
# Always give = data = cars when you use hue function, providing dataset.

# %%
sns.lmplot(data = cars,x ='Age', y ='Price', fit_reg = False, hue='FuelType', legend = True, palette="Set2")

#  palette="Set2" this is kind color theme.

# %%
sns.distplot(cars['Age'])

# same age cars display.

# %%
sns.distplot(cars['Price'])

# The distplot represents the univariate distribution of data i.e. 
# data distribution of a variable against the density distribution.

# %%
sns.distplot(cars['Age'], kde = False)

# By default, seaborn plots both kernel density estimation and histogram, 
# kde=False means you want to hide it and only display the histogram.

# %%
# I want to print only few age values.

sns.distplot(cars['Age'], kde = False , bins = 5)

# bins = 5 , beacause I want only 5 age values.

# %%
# Drawing Bar plot of  fuel-types.

sns.countplot(x='FuelType', data=cars)

# %%
# For every fuel type there is two typws of cars i.e AMT and manual.

sns.countplot(x='FuelType', data = cars, hue = 'Automatic')

# here in my data only petrol cars has two types.

# %%
# A crosstab is a table showing the relationship between two or more variables.

# making frequency table of car  fuel-types

# Calculate Frequency

pd.crosstab(index=cars['Automatic'], columns=cars['FuelType'], dropna = True)

#  0 = manual and 1 = AMT
# Out:
# FuelType   CNG  Diesel  Petrol
# Automatic
# 0           15     144    1104
# 1            0       0      73

# %%
sns.boxplot(x=cars['FuelType'], y = cars['Price'])

# %% [markdown]
# <h2 style="color:green">Box Plot Sample</h2>
#
# ![box_plot.png](attachment:box_plot.png)

# %%
sns.boxplot(x=cars['FuelType'], y = cars['Price'], hue="Automatic", data=cars)

# taking 3rd parameter which is Automatic using hue .

# %%
# creating a figure composed of two matplotlib.Axes objects (ax_box and ax_hist)

f,(ax_box,ax_hist)=plt.subplots(2,gridspec_kw={"height_ratios": (.15,.85)})


# "height_ratios": (.15,.85) , for first graph I have given 15% space and 2nd graph 85% space given.

# %%
f,(ax_box,ax_hist)=plt.subplots(2,gridspec_kw={"height_ratios": (.15,.85)})
sns.boxplot(cars['Price'],ax=ax_box)
sns.distplot(cars['Price'],ax=ax_hist, kde=False)

# In first 15% part I want to prinbt box plot of price
# In second 85% part I wnat to print histogram with no line thats y kde=False

# %% [markdown]
# <h2 style="color:green">Pair Plot</h2>

# %%
sns.pairplot(cars, kind = 'scatter', hue = 'FuelType', diag_kws={'bw' : 0.1})
plt.show

# diag_kws={'bw' : 0.1}  Im giving 10% part to every graph.
# For Scatter plot we need tow sets of values , but where Two values are not available automatically It will drow Histogrm .
# Out:
# C:\Users\MSCIT\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\MSCIT\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# creating Matrix of 10 x 10 size

data=np.random.randint(1, 100, size = (10,10))
print("The Data to be Plotted : \n")
print(data)

# size = (10,10) is my Matrix size
# Out:
# The Data to be Plotted :
#
# [[57 27 35 17 77 27 11 88 58 20]
#  [79  9 92 28 16 41 13 41 47 78]
#  [87 83  7 24 42 71  3 64 26 25]
#  [41  4 60 45  8 91 70 29  5  6]
#  [95 61 35 69 16 14  6 52 54 12]
#  [68 14 37 95 89 56 83 22 67 49]
#  [20  1 50 69 86 55 69 77 61 84]
#  [75 47 91 58  8 14 67 43 17  3]
#  [60 10 18 15 13 21 83 44 63 94]
#  [ 8 66 96 63  2 66  9 23 19 82]]

# %%
# Plotting Heat Map of above Matrix.

hm=sns.heatmap(data=data)
plt.show()

# %%
hm=sns.heatmap(data=data,
              vmin='30',
              vmax='70')
plt.show()

# vmin='30', vmax='70' I am giving color range / limit

# %%
# To change the color code of Heat Map

cmap = "tab20"
center = 0

annot = True
hm = sns.heatmap(data=data, cmap=cmap, annot=annot)
plt.show()

# cmap = "tab20" is my color theme
# annot = True Printing values in box
# center = 0 Numbers printed in center
